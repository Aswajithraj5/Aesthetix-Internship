# %% [markdown]
# <a href="https://colab.research.google.com/github/Aswajithraj5/Aesthetix-Internship/blob/main/Internship_Day4(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/preprocessing_practice_dataset.csv')
df
# Out:
#     Employee_ID   Age  Gender Department  Education  Experience_Years  \
# 0          1001  59.0    Male         HR    Masters                18
# 1          1002  49.0  Female  Marketing  Bachelors                16
# 2          1003  35.0  Female         HR        NaN                19
# 3          1004  28.0  Female         HR        PhD                 9
# 4          1005  41.0    Male         IT  Bachelors                 5
# ..          ...   ...     ...        ...        ...               ...
# 95         1096  54.0  Female         HR    Masters                11
# 96         1097  53.0    Male  Marketing    Masters                13
# 97         1098  43.0    Male        NaN        PhD                 1
# 98         1099  44.0  Female  Marketing        PhD                18
# 99         1100  57.0  Female        NaN        NaN                17
#
#     Monthly_Salary  Performance_Rating        City Attrition
# 0          52350.0                   5     Calicut        No
# ...

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Age', 'Gender', 'Department', 'Education',
#        'Experience_Years', 'Monthly_Salary', 'Performance_Rating', 'City',
#        'Attrition'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Employee_ID        Age  Experience_Years  Monthly_Salary  \
# count   100.000000  90.000000        100.000000       90.000000
# mean   1050.500000  39.866667          9.360000    75111.988889
# std      29.011492  11.015005          6.210971    28068.924984
# min    1001.000000  21.000000          0.000000    25412.000000
# 25%    1025.750000  29.250000          4.000000    50536.250000
# 50%    1050.500000  41.000000         10.000000    72715.500000
# 75%    1075.250000  48.000000         15.000000    99079.000000
# max    1100.000000  59.000000         19.000000   119297.000000
#
#        Performance_Rating
# count          100.000000
# mean             3.230000
# std              1.476106
# min              1.000000
# 25%              2.000000
# 50%              4.000000
# 75%              5.000000
# max              5.000000

# %%
df.isnull().sum()
# Out:
# Employee_ID            0
# Age                   10
# Gender                 0
# Department            10
# Education             10
# Experience_Years       0
# Monthly_Salary        10
# Performance_Rating     0
# City                  10
# Attrition              0
# dtype: int64

# %%
df['Age_mean_imputed'] = df['Age'].fillna(df['Age'].mean())
df['Age_mean_imputed']
# Out:
# 0     59.0
# 1     49.0
# 2     35.0
# 3     28.0
# 4     41.0
#       ...
# 95    54.0
# 96    53.0
# 97    43.0
# 98    44.0
# 99    57.0
# Name: Age_mean_imputed, Length: 100, dtype: float64

# %%
df['Salary_mean_imputed'] = df['Monthly_Salary'].fillna(df['Monthly_Salary'].mean())
df['Salary_mean_imputed']
# Out:
# 0      52350.0
# 1     118008.0
# 2     119297.0
# 3      50351.0
# 4     113668.0
#         ...
# 95     48625.0
# 96    107873.0
# 97     97592.0
# 98    102052.0
# 99     69261.0
# Name: Salary_mean_imputed, Length: 100, dtype: float64

# %%
df['Education_mode_imputed'] = df['Education'].fillna(df['Education'].mode()[0])#counts from first index onwards and replace NuN  value by most repeated value/term
df['Education_mode_imputed']
# Out:
# 0       Masters
# 1     Bachelors
# 2       Masters
# 3           PhD
# 4     Bachelors
#         ...
# 95      Masters
# 96      Masters
# 97          PhD
# 98          PhD
# 99      Masters
# Name: Education_mode_imputed, Length: 100, dtype: object

# %%
df['City_mode_imputed'] = df['City'].fillna(df['City'].mode()[0])#counts from first index onwards and replace NuN  value by most repeated value/term
df['City_mode_imputed']
# Out:
# 0        Calicut
# 1        Chennai
# 2          Kochi
# 3     Trivandrum
# 4     Trivandrum
#          ...
# 95       Chennai
# 96    Trivandrum
# 97       Chennai
# 98       Calicut
# 99       Calicut
# Name: City_mode_imputed, Length: 100, dtype: object

# %%
df['Department_mode_imputed'] = df['Department'].fillna(df['Department'].mode()[0])#counts from first index onwards and replace NuN  value by most repeated value/term
df['Department_mode_imputed']
# Out:
# 0            HR
# 1     Marketing
# 2            HR
# 3            HR
# 4            IT
#         ...
# 95           HR
# 96    Marketing
# 97           HR
# 98    Marketing
# 99           HR
# Name: Department_mode_imputed, Length: 100, dtype: object

# %%
df[['Age','Age_mean_imputed','Monthly_Salary','Salary_mean_imputed','City','City_mode_imputed','Education','Education_mode_imputed','Department','Department_mode_imputed']]
# Out:
#      Age  Age_mean_imputed  Monthly_Salary  Salary_mean_imputed        City  \
# 0   59.0              59.0         52350.0              52350.0     Calicut
# 1   49.0              49.0        118008.0             118008.0     Chennai
# 2   35.0              35.0        119297.0             119297.0       Kochi
# 3   28.0              28.0         50351.0              50351.0  Trivandrum
# 4   41.0              41.0        113668.0             113668.0  Trivandrum
# ..   ...               ...             ...                  ...         ...
# 95  54.0              54.0         48625.0              48625.0     Chennai
# 96  53.0              53.0        107873.0             107873.0  Trivandrum
# 97  43.0              43.0         97592.0              97592.0     Chennai
# 98  44.0              44.0        102052.0             102052.0     Calicut
# 99  57.0              57.0         69261.0              69261.0     Calicut
#
# ...

# %%
df.isnull().sum()
# Out:
# Employee_ID                 0
# Age                        10
# Gender                      0
# Department                 10
# Education                  10
# Experience_Years            0
# Monthly_Salary             10
# Performance_Rating          0
# City                       10
# Attrition                   0
# Age_mean_imputed            0
# Salary_mean_imputed         0
# Education_mode_imputed      0
# City_mode_imputed           0
# Department_mode_imputed     0
# dtype: int64

# %%
import pandas as pd #for data manipulation, numpy is for numerical manipulation
import seaborn as sns # data visualization, uses complex graphs
import matplotlib.pyplot as plt #data visualization

sns.set(style="whitegrid")

plt.figure(figsize=(10, 6))
sns.boxplot(data=df, y='Salary_mean_imputed', x='Department_mode_imputed', palette='pastel')

plt.title('Box Plot of Salary by Department',fontsize=16)
plt.xlabel('Department',fontsize=12)
plt.ylabel('Salary',fontsize=12)
plt.show()
# Out:
# /tmp/ipykernel_2435/2706360645.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, y='Salary_mean_imputed', x='Department_mode_imputed', palette='pastel')

# %%
import pandas as pd #for data manipulation, numpy is for numerical manipulation
import seaborn as sns # data visualization, uses complex graphs
import matplotlib.pyplot as plt #data visualization

sns.set(style="whitegrid")

plt.figure(figsize=(10, 6))
sns.boxplot(data=df, y='Performance_Rating', x='Experience_Years', palette='pastel')

plt.title('Box Plot of Rating by Experience',fontsize=16)
plt.xlabel('Experience',fontsize=12)
plt.ylabel('Rating',fontsize=12)
plt.show()
# Out:
# /tmp/ipykernel_2435/3454092496.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, y='Performance_Rating', x='Experience_Years', palette='pastel')

# %%
numerical_features=df.select_dtypes(include=['float64','int64'])
skewness=numerical_features.skew().sort_values(ascending=False)
print("Skewness of Numerical Features:")
print(skewness)
# Out:
# Skewness of Numerical Features:
# Age_mean_imputed       0.037075
# Age                    0.035232
# Employee_ID            0.000000
# Experience_Years      -0.029220
# Monthly_Salary        -0.076502
# Salary_mean_imputed   -0.080503
# Performance_Rating    -0.272580
# dtype: float64

# %%
# Plot distributions of numerical features
import matplotlib.pyplot as plt
plt.figure(figsize=(25, 20))
for i, column in enumerate(numerical_features.columns, 1):
    plt.subplot((len(numerical_features.columns) // 3) + 1, 3, i)
    sns.histplot(df[column].dropna(), kde=True, bins=30, color='blue')
    plt.title(f'{column} (Skewness: {skewness[column]:.2f})', fontsize=10)
    plt.xlabel(column, fontsize=8)
    plt.ylabel('Frequency', fontsize=8)

plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

encoded_data = company_data.copy()

# 1. Label Encoding for 'Sex'
label_encoder= LabelEncoder()
encoded_data['Gender_Label'] = label_encoder.fit_transform(encoded_data['Gender'])

# 2. One-Hot Encoding for 'Embarked'
one_hot_encoded = pd.get_dummies(encoded_data['Department'], prefix='Department')
encoded_data = pd.concat([encoded_data, one_hot_encoded], axis=1)


# Display the resulting dataset with relevant encoded columns
print(encoded_data[['Gender', 'Gender_Label', 'Department','Department_IT','Department_HR','Department_Marketing','Department_Finance','Department_Sales' ]].head())
# Out:
#    Gender  Gender_Label Department  Department_IT  Department_HR  \
# 0    Male             1         HR          False           True
# 1  Female             0  Marketing          False          False
# 2  Female             0         HR          False           True
# 3  Female             0         HR          False           True
# 4    Male             1         IT           True          False
#
#    Department_Marketing  Department_Finance  Department_Sales
# 0                 False               False             False
# 1                  True               False             False
# 2                 False               False             False
# 3                 False               False             False
# 4                 False               False             False

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler
company_data=pd.read_csv("/content/preprocessing_practice_dataset.csv")
company_data
# Out:
#     Employee_ID   Age  Gender Department  Education  Experience_Years  \
# 0          1001  59.0    Male         HR    Masters                18
# 1          1002  49.0  Female  Marketing  Bachelors                16
# 2          1003  35.0  Female         HR        NaN                19
# 3          1004  28.0  Female         HR        PhD                 9
# 4          1005  41.0    Male         IT  Bachelors                 5
# ..          ...   ...     ...        ...        ...               ...
# 95         1096  54.0  Female         HR    Masters                11
# 96         1097  53.0    Male  Marketing    Masters                13
# 97         1098  43.0    Male        NaN        PhD                 1
# 98         1099  44.0  Female  Marketing        PhD                18
# 99         1100  57.0  Female        NaN        NaN                17
#
#     Monthly_Salary  Performance_Rating        City Attrition
# 0          52350.0                   5     Calicut        No
# ...

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler
company_data=pd.read_csv("/content/preprocessing_practice_dataset.csv")

# Select numerical columns for scaling
numerical_columns = ['Age', 'Monthly_Salary', 'Department']

# Drop rows with missing values for simplicity
company_data.dropna(subset=numerical_columns, inplace=True)

# Initialize scalers
minmax_scaler = MinMaxScaler()
standard_scaler = StandardScaler()

# Apply Min-Max Scaling
company_data['Age_MinMax'] = minmax_scaler.fit_transform(company_data[['Age']])
company_data['Salary_MinMax'] = minmax_scaler.fit_transform(company_data[['Monthly_Salary']])

# Apply Standard Scaling
company_data['Age_Standard'] = standard_scaler.fit_transform(company_data[['Age']])
company_data['Salary_Standard'] = standard_scaler.fit_transform(company_data[['Monthly_Salary']])


# Display scaled features
company_data[['Age', 'Age_MinMax', 'Age_Standard','Salary_MinMax','Salary_Standard']].head()
# Out:
#     Age  Age_MinMax  Age_Standard  Salary_MinMax  Salary_Standard
# 0  59.0    1.000000      1.826366       0.286925        -0.756113
# 1  49.0    0.736842      0.902715       0.986270         1.552017
# 2  35.0    0.368421     -0.390396       1.000000         1.597330
# 3  28.0    0.184211     -1.036952       0.265633        -0.826386
# 4  41.0    0.526316      0.163794       0.940044         1.399449

# %% [markdown]
# # **Image Processing/Computer Vision**

# %%
from PIL import Image
image=Image.open("/content/fifa2026.png")
image

# %% [markdown]
# **Image Resizing**

# %%
image_resize=image.resize((400,300))
image_resize
# Out:
# <PIL.Image.Image image mode=RGB size=400x300>

# %%
import numpy as np
image_array=np.array(image_resize)
image_array
# Out:
# array([[[183, 243, 254],
#         [229, 255, 255],
#         [236, 255, 254],
#         ...,
#         [237, 255, 255],
#         [237, 255, 255],
#         [237, 255, 255]],
#
#        [[157, 219, 254],
#         [221, 255, 254],
#         [236, 255, 254],
#         ...,
#         [237, 255, 255],
#         [237, 255, 255],
#         [237, 255, 255]],
#
#        [[113, 175, 232],
#         [206, 253, 255],
#         [235, 255, 254],
#         ...,
#         [237, 255, 255],
#         [237, 255, 255],
#         [237, 255, 255]],
#
#        ...,
#
#        [[ 83, 119,  37],
#         [ 96, 128,  48],
#         [ 81, 116,  33],
#         ...,
#         [ 75,  97,  38],
#         [ 72,  97,  34],
#         [ 78, 100,  35]],
#
#        [[ 74, 113,  26],
#         [ 78, 113,  31],
#         [ 81, 114,  36],
#         ...,
#         [ 73,  97,  37],
#         [ 64,  88,  25],
#         [ 73,  98,  36]],
#
#        [[ 76, 116,  30],
#         [ 86, 123,  43],
#         [ 84, 117,  38],
# ...

# %%
image_array=np.array(image_resize)/255.0
image_array
# Out:
# array([[[0.71764706, 0.95294118, 0.99607843],
#         [0.89803922, 1.        , 1.        ],
#         [0.9254902 , 1.        , 0.99607843],
#         ...,
#         [0.92941176, 1.        , 1.        ],
#         [0.92941176, 1.        , 1.        ],
#         [0.92941176, 1.        , 1.        ]],
#
#        [[0.61568627, 0.85882353, 0.99607843],
#         [0.86666667, 1.        , 0.99607843],
#         [0.9254902 , 1.        , 0.99607843],
#         ...,
#         [0.92941176, 1.        , 1.        ],
#         [0.92941176, 1.        , 1.        ],
#         [0.92941176, 1.        , 1.        ]],
#
#        [[0.44313725, 0.68627451, 0.90980392],
#         [0.80784314, 0.99215686, 1.        ],
#         [0.92156863, 1.        , 0.99607843],
#         ...,
#         [0.92941176, 1.        , 1.        ],
#         [0.92941176, 1.        , 1.        ],
#         [0.92941176, 1.        , 1.        ]],
#
#        ...,
#
#        [[0.3254902 , 0.46666667, 0.14509804],
# ...

# %%
from cv2 import cvtColor, COLOR_BGR2GRAY
image_np=np.array(image_resize)
image_gray=cvtColor(image_np,COLOR_BGR2GRAY)
image_gray
# Out:
# array([[239, 252, 253, ..., 253, 253, 253],
#        [222, 251, 253, ..., 253, 253, 253],
#        [185, 248, 252, ..., 253, 253, 253],
#        ...,
#        [ 90, 100,  87, ...,  77,  75,  78],
#        [ 83,  84,  87, ...,  76,  66,  77],
#        [ 86,  95,  90, ...,  81,  79,  84]], dtype=uint8)

# %% [markdown]
# # **Data Augmentation**

# %% [markdown]
# data augmentation-photo editing
# filtering-key point detection on image

# %%
from PIL import Image,ImageEnhance,ImageOps
flipped=ImageOps.mirror(image)
flipped

# %%
rotated=image.rotate(30)
rotated

# %%
enhancer=ImageEnhance.Brightness(image)
brighter=enhancer.enhance(2.5)
brighter

# %%
contrast =ImageEnhance.Contrast(image).enhance(2.5)
contrast

# %%
grayscale=ImageOps.grayscale(image)
grayscale
# Out:
# <PIL.Image.Image image mode=L size=1920x1080>
